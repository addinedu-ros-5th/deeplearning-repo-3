# %%
import cv2
import pandas as pd
from collections import defaultdict, deque, Counter
from statistics import mode
from ultralytics import YOLO

class VehicleDetector:
    def __init__(self, model_path, min_vehicle_size=1000):
        self.model_path = model_path
        self.min_vehicle_size = min_vehicle_size
        self.model = YOLO(model_path)
        self.img_width = 1280  # 영상의 가로 해상도
        self.img_height = 720  # 영상의 세로 해상도
        self.center_line_x = self.img_width // 2  # 영상의 중앙선 x 좌표
        self.center_line_tolerance = 70  # 중앙선 허용 오차
        self.last_bbox_size = 0
        self.classes = {
            0: "person",
            1: "bicycle",
            2: "car",
            3: "motorcycle",
            4: "airplane",
            5: "bus",
            6: "train",
            7: "truck",
            8: "boat",
            9: "traffic light",
            10: "fire hydrant",
            11: "stop sign",
            12: "parking meter",
            # Add more classes if needed
        }
        self.pass_fail_status_history = defaultdict(lambda: deque(maxlen=10))  # 최대 10개 항목 저장
        self.pass_fail_status = {}

    def check_front_vehicle(self, frame):
        frame = cv2.resize(frame, (self.img_width, self.img_height))
        results = self.model.track(frame, persist=True)

        is_crash = 0  # 초기 값 설정
        x1, y1, x2, y2, track_id, class_id = 0, 0, 0, 0, 0, 0  # 초기 값 설정

        for box in results[0].boxes:
            # 바운딩 박스의 중심 좌표 계산
            x_center = (box.xyxy[0][0] + box.xyxy[0][2]) // 2
            y_center = (box.xyxy[0][1] + box.xyxy[0][3]) // 2
            # 중앙선을 통과하는지 확인
            if self.center_line_x - self.center_line_tolerance < x_center < self.center_line_x + self.center_line_tolerance:
                # 바운딩 박스의 크기 계산
                box_size = box.xywh[0][2] * box.xywh[0][3]
                # 자동차 클래스 필터링 및 크기 조건 검사
                if 20000 < box_size < 80000:
                    is_crash = 1  # 전방 차량이 감지됨
                elif box_size > 80000:
                    is_crash = 2  # 전방 차량이 감지됨 충돌 직전
                    if box.id is not None:  # None이 아닌 경우에만 track_id 설정
                        track_id = int(box.id)  # 클래스 ID 추출
                        class_id = int(box.cls)
                
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                break  # 첫 번째 바운딩 박스만 고려

        return is_crash, x1, y1, x2, y2, track_id, class_id

    def determine_driving_status(self, current_bbox_size):
        # 이전 프레임과의 바운딩 박스 크기 비교
        size_difference = abs(current_bbox_size - self.last_bbox_size)
        # 크기 변화량을 기준으로 주행 상태 판단
        if size_difference > 1000:  # 예시로 1000을 기준으로 주행 중으로 판단
            return True  # 주행 중
        else:
            return False  # 정지 중

    def update_last_bbox_size(self, current_bbox_size):
        self.last_bbox_size = current_bbox_size

    def determine_pass_fail_status(self, is_driving):
        return 'Fail' if is_driving else 'Pass'

class TrafficLightDetector:
    def __init__(self, model_path, history_length=30):
        self.model = YOLO(model_path)
        self.desired_width = 1280
        self.desired_height = 720
        self.history_length = history_length
        self.size_history = defaultdict(lambda: deque(maxlen=history_length))
        self.pass_fail_status_history = defaultdict(lambda: deque(maxlen=10))  # pass/fail 상태 기록
        self.pass_fail_status = defaultdict(lambda: "Calculating")  # 초기값을 "Calculating"으로 설정
        self.signal_detected = False
        self.signal_color = defaultdict(lambda: None)
        self.classes = {
            0: 'Red',
            1: 'Red and Green Arrow',
            2: 'Green',
            3: 'Yellow',
            4: 'Green and Green Arrow',
            5: 'Green Arrow'
        }
        self.detected_ids = set()  # 추적된 신호등 ID를 저장하는 집합

    def detect_traffic_light(self, frame):
        frame = cv2.resize(frame, (self.desired_width, self.desired_height))
        results = self.model.track(frame, persist=True)
        detected_objects = []

        if results[0].boxes.is_track:
            self.signal_detected = True
            max_size = 0
            max_obj_id = None
            for detection in results[0].boxes.data:
                x1, y1, x2, y2, obj_id, _, class_id = map(int, detection[:7])
                size = (x2 - x1) * (y2 - y1)  # 신호등 크기 계산
                # 가장 크기가 큰 객체만 선택
                if size > max_size:
                    max_size = size
                    max_obj_id = obj_id

            if max_obj_id is not None:
                detected_objects.append((max_obj_id, max_size))
                self.detected_ids.add(max_obj_id)  # 감지된 신호등 ID 추가
                self.signal_color[max_obj_id] = self.classes.get(class_id, None)

                # 업데이트된 크기 히스토리
                self.size_history[max_obj_id].append(max_size)

                # 객체가 발견된 경우에만 Pass/Fail 상태 업데이트
                is_driving = self.check_driving_status(max_obj_id)
                pass_fail = self.determine_pass_fail_status(is_driving, class_id)
                self.pass_fail_status_history[max_obj_id].append(pass_fail)  # 최근 10프레임의 Pass/Fail 기록

                # 객체의 Pass/Fail 값을 최근 10프레임 동안의 데이터를 기반으로 판단
                if len(self.pass_fail_status_history[max_obj_id]) == 10:
                    self.pass_fail_status[max_obj_id] = mode(self.pass_fail_status_history[max_obj_id])

        else:
            self.signal_detected = False

        return detected_objects, results


    def check_driving_status(self, obj_id):
        # 신호등 크기의 변화를 확인하여 주행 상태 판단
        if len(self.size_history[obj_id]) == self.history_length:
            # 최근 크기 변화 계산
            recent_changes = max(self.size_history[obj_id]) - min(self.size_history[obj_id])
            # 주행 상태 판단: 크기 변화가 있는 경우 주행 중으로 판단
            if recent_changes > threshold:
                return True
        # 주행 상태 판단: 크기 변화가 없는 경우 정지 중으로 판단
        return False

    def determine_pass_fail_status(self, is_driving, class_id):
        if is_driving and class_id in [0, 1]:
            Pass_Fail = "Fail"
        elif is_driving and class_id in [2, 3, 4, 5]:
            Pass_Fail = "Pass"
        elif not is_driving and class_id in [0, 1]:
            Pass_Fail = "Pass"
        elif not is_driving and class_id in [2, 3, 4, 5]:
            Pass_Fail = "Fail"
        return Pass_Fail

def main(video_path, vehicle_model_path, traffic_light_model_path):
    cap = cv2.VideoCapture(video_path)
    vehicle_detector = VehicleDetector(vehicle_model_path)
    traffic_light_detector = TrafficLightDetector(traffic_light_model_path)
    df_data = []
    frame_count = 0

    while cap.isOpened():
        success, frame = cap.read()
        if not success:
            break
        
        frame_count += 1

        # 신호등 감지
        detected_objects, results = traffic_light_detector.detect_traffic_light(frame)
        if results[0].boxes.is_track:
            for detection in results[0].boxes.data:
                traffic_x1, traffic_y1, traffic_x2, traffic_y2, obj_id, _, class_id = map(int, detection[:7])
                cv2.rectangle(frame, (traffic_x1, traffic_y1), (traffic_x2, traffic_y2), (0,255,0), 2)

        # 차량 감지
        vehicle_is_crash, x1, y1, x2, y2, track_id, class_id = vehicle_detector.check_front_vehicle(frame)
        
        # 차량 바운딩 박스 색상 설정
        vehicle_color = (0, 255, 0)  # 초록색
        if vehicle_is_crash == 1:
            vehicle_color = (0, 165, 255)  # 주황색
        elif vehicle_is_crash == 2:
            vehicle_color = (0, 0, 255)  # 빨간색

        # 차량 바운딩 박스 그리기
        cv2.rectangle(frame, (x1, y1), (x2, y2), vehicle_color, 2)
        

        # 차량 주행 상태 판별 및 업데이트
        if vehicle_is_crash == 2:  # 충돌 직전인 경우에만 주행 상태를 판별하고 출력하고 저장
            current_bbox_size = (x2 - x1) * (y2 - y1)
            vehicle_is_driving = vehicle_detector.determine_driving_status(current_bbox_size)
            vehicle_detector.update_last_bbox_size(current_bbox_size)

            if track_id:
                vehicle_pass_fail = vehicle_detector.determine_pass_fail_status(vehicle_is_driving)
                vehicle_detector.pass_fail_status_history[track_id].append(vehicle_pass_fail)

                # 최종 10개 데이터 기반 판단
                if len(vehicle_detector.pass_fail_status_history[track_id]) == 10:
                    vehicle_detector.pass_fail_status[track_id] = mode(vehicle_detector.pass_fail_status_history[track_id])
                else:
                    vehicle_detector.pass_fail_status[track_id] = vehicle_pass_fail

                # 차량 주행 상태에 따라 표시할 메시지 설정
                vehicle_status_msg = "Driving" if vehicle_is_driving else "Stopped"
                vehicle_pass_fail = vehicle_detector.pass_fail_status[track_id]

                # 화면에 차량 주행 상태 출력
                cv2.putText(frame, f"Vehicle ID: {track_id} Status: {vehicle_status_msg} Pass/Fail: {vehicle_pass_fail}", 
                            (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, vehicle_color, 2, cv2.LINE_AA)

                # 데이터프레임에 차량 주행 상태 저장
                df_data.append({'Object_Type': 'Vehicle', 'ID': track_id, 'Status': vehicle_status_msg, 'Pass/Fail': vehicle_pass_fail})

        # 신호등 바운딩 박스 및 정보 출력
        for obj_id, size in detected_objects:
            # 신호등 바운딩 박스 및 정보 출력
            status = "DRIVING" if traffic_light_detector.check_driving_status(obj_id) else "STOP"
            signal_color = traffic_light_detector.signal_color[obj_id]
            
            # 데이터프레임에 신호등 정보 저장
            if signal_color is not None:
                pass_fail = traffic_light_detector.pass_fail_status[obj_id]
                cv2.putText(frame, f"Traffic Light ID: {obj_id} Status: {status}", (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
                cv2.putText(frame, f"Signal color: {signal_color}", (20, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)
                cv2.putText(frame, f"Pass/Fail: {pass_fail}", (20, 200), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
                if pass_fail != "Calculating":
                # 데이터프레임에 신호등 정보 저장
                    df_data.append({'Object_Type': 'Traffic Light', 'ID': obj_id, 'Status': status, 'Signal Color': signal_color, 'Pass/Fail': pass_fail})

        # 화면에 프레임 출력
        cv2.imshow("Frame", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    # 결과 데이터프레임 생성
    df = pd.DataFrame(df_data)

    # 중복된 ID에 대해 최다빈도수 값만 남기고 나머지는 제거
    df = df.groupby('ID').agg(lambda x: Counter(x).most_common(1)[0][0]).reset_index()

    # 데이터프레임 출력
    print(df)

    # 데이터프레임을 CSV 파일로 저장
    df.to_csv('combined_detection_results.csv', index=False)

if __name__ == "__main__":
    video_path = "/home/min/dev_ws/machine_learning/project_3rd/data/TEST_VIDEO/6_Fail_Pedestrian_Red_Light.MOV"
    vehicle_model_path = "/home/min/dev_ws/machine_learning/project_3rd/src/judge_video/lane_detect/yolov8n.pt"
    traffic_light_model_path = "/home/min/dev_ws/machine_learning/project_3rd/src/model_learning/traffic_light/traffic_best_ver2.pt"
    threshold = 30  # 주행 상태 판단을 위한 임계값 설정
    main(video_path, vehicle_model_path, traffic_light_model_path)
# Out:
# 0: 384x640 (no detections), 320.3ms
# Speed: 7.4ms preprocess, 320.3ms inference, 509.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 198.8ms
# Speed: 2.2ms preprocess, 198.8ms inference, 479.7ms postprocess per image at shape (1, 3, 384, 640)
# QFactoryLoader::QFactoryLoader() checking directory path "/home/min/venv/yolo/lib/python3.10/site-packages/cv2/qt/plugins" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/bin" ...
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/411toppm"
# "Failed to extract plugin meta data from '/usr/bin/411toppm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/7z"
# QElfParser: '/usr/bin/7z' is not an ELF object (file too small)
# "'/usr/bin/7z' is not an ELF object (file too small)"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/7za"
# QElfParser: '/usr/bin/7za' is not an ELF object (file too small)
# "'/usr/bin/7za' is not an ELF object (file too small)"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/7zr"
# QElfParser: '/usr/bin/7zr' is not an ELF object (file too small)
# "'/usr/bin/7zr' is not an ELF object (file too small)"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/["
# "Failed to extract plugin meta data from '/usr/bin/['"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aa-enabled"
# "Failed to extract plugin meta data from '/usr/bin/aa-enabled'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aa-exec"
# "Failed to extract plugin meta data from '/usr/bin/aa-exec'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aa-features-abi"
# "Failed to extract plugin meta data from '/usr/bin/aa-features-abi'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aclocal"
# QElfParser: '/usr/bin/aclocal-1.16' is not an ELF object
# "'/usr/bin/aclocal-1.16' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aclocal-1.16"
# QElfParser: '/usr/bin/aclocal-1.16' is not an ELF object
# "'/usr/bin/aclocal-1.16' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aconnect"
# "Failed to extract plugin meta data from '/usr/bin/aconnect'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/acpi_listen"
# "Failed to extract plugin meta data from '/usr/bin/acpi_listen'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/activate-global-python-argcomplete3"
# QElfParser: '/usr/bin/activate-global-python-argcomplete3' is not an ELF object
# "'/usr/bin/activate-global-python-argcomplete3' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/acyclic"
# "Failed to extract plugin meta data from '/usr/bin/acyclic'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/add-apt-repository"
# QElfParser: '/usr/bin/add-apt-repository' is not an ELF object
# "'/usr/bin/add-apt-repository' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/addpart"
# "Failed to extract plugin meta data from '/usr/bin/addpart'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/addr2line"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-addr2line'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aggregate_profile"
# QElfParser: '/usr/bin/aggregate_profile' is not an ELF object
# "'/usr/bin/aggregate_profile' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/airscan-discover"
# "Failed to extract plugin meta data from '/usr/bin/airscan-discover'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/alsabat"
# "Failed to extract plugin meta data from '/usr/bin/alsabat'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/alsaloop"
# "Failed to extract plugin meta data from '/usr/bin/alsaloop'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/alsamixer"
# "Failed to extract plugin meta data from '/usr/bin/alsamixer'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/alsatplg"
# "Failed to extract plugin meta data from '/usr/bin/alsatplg'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/alsaucm"
# "Failed to extract plugin meta data from '/usr/bin/alsaucm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/amidi"
# "Failed to extract plugin meta data from '/usr/bin/amidi'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/amixer"
# "Failed to extract plugin meta data from '/usr/bin/amixer'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/animate"
# "Failed to extract plugin meta data from '/usr/bin/animate-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/animate-im6"
# "Failed to extract plugin meta data from '/usr/bin/animate-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/animate-im6.q16"
# "Failed to extract plugin meta data from '/usr/bin/animate-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/anytopnm"
# QElfParser: '/usr/bin/anytopnm' is not an ELF object
# "'/usr/bin/anytopnm' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apg"
# QElfParser: '/usr/bin/apg' is not an ELF object
# "'/usr/bin/apg' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apgbfm"
# "Failed to extract plugin meta data from '/usr/bin/apgbfm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aplay"
# "Failed to extract plugin meta data from '/usr/bin/aplay'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aplaymidi"
# "Failed to extract plugin meta data from '/usr/bin/aplaymidi'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apport-bug"
# QElfParser: '/usr/bin/apport-bug' is not an ELF object
# "'/usr/bin/apport-bug' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apport-cli"
# QElfParser: '/usr/bin/apport-cli' is not an ELF object
# "'/usr/bin/apport-cli' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apport-collect"
# QElfParser: '/usr/bin/apport-bug' is not an ELF object
# "'/usr/bin/apport-bug' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apport-unpack"
# QElfParser: '/usr/bin/apport-unpack' is not an ELF object
# "'/usr/bin/apport-unpack' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/appres"
# "Failed to extract plugin meta data from '/usr/bin/appres'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/appstreamcli"
# "Failed to extract plugin meta data from '/usr/bin/appstreamcli'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apropos"
# "Failed to extract plugin meta data from '/usr/bin/whatis'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt"
# "Failed to extract plugin meta data from '/usr/bin/apt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-add-repository"
# QElfParser: '/usr/bin/add-apt-repository' is not an ELF object
# "'/usr/bin/add-apt-repository' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-cache"
# "Failed to extract plugin meta data from '/usr/bin/apt-cache'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-cdrom"
# "Failed to extract plugin meta data from '/usr/bin/apt-cdrom'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-config"
# "Failed to extract plugin meta data from '/usr/bin/apt-config'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-extracttemplates"
# "Failed to extract plugin meta data from '/usr/bin/apt-extracttemplates'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-ftparchive"
# "Failed to extract plugin meta data from '/usr/bin/apt-ftparchive'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-get"
# "Failed to extract plugin meta data from '/usr/bin/apt-get'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-key"
# QElfParser: '/usr/bin/apt-key' is not an ELF object
# "'/usr/bin/apt-key' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-mark"
# "Failed to extract plugin meta data from '/usr/bin/apt-mark'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apt-sortpkgs"
# "Failed to extract plugin meta data from '/usr/bin/apt-sortpkgs'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aptdcon"
# QElfParser: '/usr/bin/aptdcon' is not an ELF object
# "'/usr/bin/aptdcon' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apturl"
# QElfParser: '/usr/bin/apturl' is not an ELF object
# "'/usr/bin/apturl' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/apturl-gtk"
# QElfParser: '/usr/bin/apturl-gtk' is not an ELF object
# "'/usr/bin/apturl-gtk' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ar"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-ar'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/arch"
# "Failed to extract plugin meta data from '/usr/bin/arch'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/arecord"
# "Failed to extract plugin meta data from '/usr/bin/aplay'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/arecordmidi"
# "Failed to extract plugin meta data from '/usr/bin/arecordmidi'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/arm2hpdl"
# "Failed to extract plugin meta data from '/usr/bin/arm2hpdl'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/as"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-as'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/asciitopgm"
# "Failed to extract plugin meta data from '/usr/bin/asciitopgm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aseqdump"
# "Failed to extract plugin meta data from '/usr/bin/aseqdump'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aseqnet"
# "Failed to extract plugin meta data from '/usr/bin/aseqnet'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aspell"
# "Failed to extract plugin meta data from '/usr/bin/aspell'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/aspell-import"
# QElfParser: '/usr/bin/aspell-import' is not an ELF object
# "'/usr/bin/aspell-import' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/assistant"
# "Failed to extract plugin meta data from '/usr/bin/qtchooser'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/atktopbm"
# "Failed to extract plugin meta data from '/usr/bin/atktopbm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/atobm"
# "Failed to extract plugin meta data from '/usr/bin/atobm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/autoconf"
# QElfParser: '/usr/bin/autoconf' is not an ELF object
# "'/usr/bin/autoconf' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/autoheader"
# QElfParser: '/usr/bin/autoheader' is not an ELF object
# "'/usr/bin/autoheader' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/autom4te"
# QElfParser: '/usr/bin/autom4te' is not an ELF object
# "'/usr/bin/autom4te' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/automake"
# QElfParser: '/usr/bin/automake-1.16' is not an ELF object
# "'/usr/bin/automake-1.16' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/automake-1.16"
# QElfParser: '/usr/bin/automake-1.16' is not an ELF object
# "'/usr/bin/automake-1.16' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/autoreconf"
# QElfParser: '/usr/bin/autoreconf' is not an ELF object
# "'/usr/bin/autoreconf' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/autoscan"
# QElfParser: '/usr/bin/autoscan' is not an ELF object
# "'/usr/bin/autoscan' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/autoupdate"
# QElfParser: '/usr/bin/autoupdate' is not an ELF object
# "'/usr/bin/autoupdate' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-browse"
# "Failed to extract plugin meta data from '/usr/bin/avahi-browse'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-browse-domains"
# "Failed to extract plugin meta data from '/usr/bin/avahi-browse'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-publish"
# "Failed to extract plugin meta data from '/usr/bin/avahi-publish'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-publish-address"
# "Failed to extract plugin meta data from '/usr/bin/avahi-publish'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-publish-service"
# "Failed to extract plugin meta data from '/usr/bin/avahi-publish'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-resolve"
# "Failed to extract plugin meta data from '/usr/bin/avahi-resolve'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-resolve-address"
# "Failed to extract plugin meta data from '/usr/bin/avahi-resolve'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-resolve-host-name"
# "Failed to extract plugin meta data from '/usr/bin/avahi-resolve'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avahi-set-host-name"
# "Failed to extract plugin meta data from '/usr/bin/avahi-set-host-name'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/avinfo"
# "Failed to extract plugin meta data from '/usr/bin/avinfo'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/awk"
# "Failed to extract plugin meta data from '/usr/bin/mawk'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/axfer"
# "Failed to extract plugin meta data from '/usr/bin/axfer'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/b2"
# "Failed to extract plugin meta data from '/usr/bin/b2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/b2sum"
# "Failed to extract plugin meta data from '/usr/bin/b2sum'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/baobab"
# "Failed to extract plugin meta data from '/usr/bin/baobab'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/base32"
# "Failed to extract plugin meta data from '/usr/bin/base32'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/base64"
# "Failed to extract plugin meta data from '/usr/bin/base64'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/basename"
# "Failed to extract plugin meta data from '/usr/bin/basename'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/basenc"
# "Failed to extract plugin meta data from '/usr/bin/basenc'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bash"
# "Failed to extract plugin meta data from '/usr/bin/bash'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bashbug"
# QElfParser: '/usr/bin/bashbug' is not an ELF object
# "'/usr/bin/bashbug' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bc"
# "Failed to extract plugin meta data from '/usr/bin/bc'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bcomps"
# "Failed to extract plugin meta data from '/usr/bin/bcomps'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bcp"
# "Failed to extract plugin meta data from '/usr/bin/bcp'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bdftopcf"
# "Failed to extract plugin meta data from '/usr/bin/bdftopcf'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bdftruncate"
# "Failed to extract plugin meta data from '/usr/bin/bdftruncate'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bin2c"
# "Failed to extract plugin meta data from '/usr/bin/bin2c'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bioradtopgm"
# "Failed to extract plugin meta data from '/usr/bin/bioradtopgm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bitmap"
# "Failed to extract plugin meta data from '/usr/bin/bitmap'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bjam"
# "Failed to extract plugin meta data from '/usr/bin/b2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bloom-export-upstream"
# QElfParser: '/usr/bin/bloom-export-upstream' is not an ELF object
# "'/usr/bin/bloom-export-upstream' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bloom-generate"
# QElfParser: '/usr/bin/bloom-generate' is not an ELF object
# "'/usr/bin/bloom-generate' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bloom-release"
# QElfParser: '/usr/bin/bloom-release' is not an ELF object
# "'/usr/bin/bloom-release' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bloom-update"
# QElfParser: '/usr/bin/bloom-update' is not an ELF object
# "'/usr/bin/bloom-update' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bluemoon"
# "Failed to extract plugin meta data from '/usr/bin/bluemoon'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bluetooth-sendto"
# "Failed to extract plugin meta data from '/usr/bin/bluetooth-sendto'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bluetoothctl"
# "Failed to extract plugin meta data from '/usr/bin/bluetoothctl'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bmptopnm"
# "Failed to extract plugin meta data from '/usr/bin/bmptopnm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bmptoppm"
# "Failed to extract plugin meta data from '/usr/bin/bmptopnm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bmtoa"
# "Failed to extract plugin meta data from '/usr/bin/bmtoa'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/boltctl"
# "Failed to extract plugin meta data from '/usr/bin/boltctl'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bootctl"
# "Failed to extract plugin meta data from '/usr/bin/bootctl'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/brltty"
# "Failed to extract plugin meta data from '/usr/bin/brltty'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/brltty-ctb"
# "Failed to extract plugin meta data from '/usr/bin/brltty-ctb'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/brltty-trtxt"
# "Failed to extract plugin meta data from '/usr/bin/brltty-trtxt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/brltty-ttb"
# "Failed to extract plugin meta data from '/usr/bin/brltty-ttb'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/broadwayd"
# "Failed to extract plugin meta data from '/usr/bin/broadwayd'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/browse"
# QElfParser: '/usr/bin/xdg-open' is not an ELF object
# "'/usr/bin/xdg-open' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/brushtopbm"
# "Failed to extract plugin meta data from '/usr/bin/brushtopbm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/brz"
# QElfParser: '/usr/bin/brz' is not an ELF object
# "'/usr/bin/brz' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/btattach"
# "Failed to extract plugin meta data from '/usr/bin/btattach'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/btmgmt"
# "Failed to extract plugin meta data from '/usr/bin/btmgmt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/btmon"
# "Failed to extract plugin meta data from '/usr/bin/btmon'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bugpoint"
# "Failed to extract plugin meta data from '/usr/lib/llvm-14/bin/bugpoint'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bugpoint-14"
# "Failed to extract plugin meta data from '/usr/lib/llvm-14/bin/bugpoint'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bunzip2"
# "Failed to extract plugin meta data from '/usr/bin/bunzip2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/busctl"
# "Failed to extract plugin meta data from '/usr/bin/busctl'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/busybox"
# "Failed to extract plugin meta data from '/usr/bin/busybox'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bwrap"
# "Failed to extract plugin meta data from '/usr/bin/bwrap'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzcat"
# "Failed to extract plugin meta data from '/usr/bin/bzcat'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzcmp"
# QElfParser: '/usr/bin/bzdiff' is not an ELF object
# "'/usr/bin/bzdiff' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzdiff"
# QElfParser: '/usr/bin/bzdiff' is not an ELF object
# "'/usr/bin/bzdiff' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzegrep"
# QElfParser: '/usr/bin/bzgrep' is not an ELF object
# "'/usr/bin/bzgrep' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzexe"
# QElfParser: '/usr/bin/bzexe' is not an ELF object
# "'/usr/bin/bzexe' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzfgrep"
# QElfParser: '/usr/bin/bzgrep' is not an ELF object
# "'/usr/bin/bzgrep' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzgrep"
# QElfParser: '/usr/bin/bzgrep' is not an ELF object
# "'/usr/bin/bzgrep' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzip2"
# "Failed to extract plugin meta data from '/usr/bin/bzip2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzip2recover"
# "Failed to extract plugin meta data from '/usr/bin/bzip2recover'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzless"
# QElfParser: '/usr/bin/bzmore' is not an ELF object
# "'/usr/bin/bzmore' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzmore"
# QElfParser: '/usr/bin/bzmore' is not an ELF object
# "'/usr/bin/bzmore' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/bzr"
# QElfParser: '/usr/bin/brz' is not an ELF object
# "'/usr/bin/brz' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/c++"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-g++-11'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/c++filt"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-c++filt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/c89"
# QElfParser: '/usr/bin/c89-gcc' is not an ELF object
# "'/usr/bin/c89-gcc' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/c89-gcc"
# QElfParser: '/usr/bin/c89-gcc' is not an ELF object
# "'/usr/bin/c89-gcc' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/c99"
# QElfParser: '/usr/bin/c99-gcc' is not an ELF object
# "'/usr/bin/c99-gcc' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/c99-gcc"
# QElfParser: '/usr/bin/c99-gcc' is not an ELF object
# "'/usr/bin/c99-gcc' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/c_rehash"
# QElfParser: '/usr/bin/c_rehash' is not an ELF object
# "'/usr/bin/c_rehash' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cabextract"
# "Failed to extract plugin meta data from '/usr/bin/cabextract'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/caf"
# QElfParser: '/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/caf' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/caf' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/caf.openmpi"
# QElfParser: '/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/caf' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/caf' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cafrun"
# QElfParser: '/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/cafrun' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/cafrun' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cafrun.openmpi"
# QElfParser: '/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/cafrun' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/cafrun' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/calibrate_ppa"
# "Failed to extract plugin meta data from '/usr/bin/calibrate_ppa'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/canberra-gtk-play"
# "Failed to extract plugin meta data from '/usr/bin/canberra-gtk-play'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cancel"
# "Failed to extract plugin meta data from '/usr/bin/cancel'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/captoinfo"
# "Failed to extract plugin meta data from '/usr/bin/tic'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cat"
# "Failed to extract plugin meta data from '/usr/bin/cat'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catkin_create_pkg"
# QElfParser: '/usr/bin/catkin_create_pkg' is not an ELF object
# "'/usr/bin/catkin_create_pkg' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catkin_find_pkg"
# QElfParser: '/usr/bin/catkin_find_pkg' is not an ELF object
# "'/usr/bin/catkin_find_pkg' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catkin_generate_changelog"
# QElfParser: '/usr/bin/catkin_generate_changelog' is not an ELF object
# "'/usr/bin/catkin_generate_changelog' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catkin_package_version"
# QElfParser: '/usr/bin/catkin_package_version' is not an ELF object
# "'/usr/bin/catkin_package_version' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catkin_prepare_release"
# QElfParser: '/usr/bin/catkin_prepare_release' is not an ELF object
# "'/usr/bin/catkin_prepare_release' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catkin_tag_changelog"
# QElfParser: '/usr/bin/catkin_tag_changelog' is not an ELF object
# "'/usr/bin/catkin_tag_changelog' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catkin_test_changelog"
# QElfParser: '/usr/bin/catkin_test_changelog' is not an ELF object
# "'/usr/bin/catkin_test_changelog' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/catman"
# "Failed to extract plugin meta data from '/usr/bin/catman'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cautious-launcher"
# QElfParser: '/usr/bin/cautious-launcher' is not an ELF object
# "'/usr/bin/cautious-launcher' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cc"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-gcc-11'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ccomps"
# "Failed to extract plugin meta data from '/usr/bin/ccomps'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cct"
# "Failed to extract plugin meta data from '/usr/bin/cct'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ccx"
# "Failed to extract plugin meta data from '/usr/bin/ccx'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cd-create-profile"
# "Failed to extract plugin meta data from '/usr/bin/cd-create-profile'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cd-fix-profile"
# "Failed to extract plugin meta data from '/usr/bin/cd-fix-profile'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cd-iccdump"
# "Failed to extract plugin meta data from '/usr/bin/cd-iccdump'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cd-it8"
# "Failed to extract plugin meta data from '/usr/bin/cd-it8'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/certutil"
# "Failed to extract plugin meta data from '/usr/bin/certutil'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cgi-fcgi"
# "Failed to extract plugin meta data from '/usr/bin/cgi-fcgi'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chacl"
# "Failed to extract plugin meta data from '/usr/bin/chacl'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chage"
# "Failed to extract plugin meta data from '/usr/bin/chage'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chardet"
# QElfParser: '/usr/bin/chardetect' is not an ELF object
# "'/usr/bin/chardetect' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chardetect"
# QElfParser: '/usr/bin/chardetect' is not an ELF object
# "'/usr/bin/chardetect' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chattr"
# "Failed to extract plugin meta data from '/usr/bin/chattr'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chcon"
# "Failed to extract plugin meta data from '/usr/bin/chcon'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/check-language-support"
# QElfParser: '/usr/bin/check-language-support' is not an ELF object
# "'/usr/bin/check-language-support' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cheese"
# "Failed to extract plugin meta data from '/usr/bin/cheese'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chfn"
# "Failed to extract plugin meta data from '/usr/bin/chfn'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chg"
# "Failed to extract plugin meta data from '/usr/bin/chg'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chgrp"
# "Failed to extract plugin meta data from '/usr/bin/chgrp'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chktest"
# "Failed to extract plugin meta data from '/usr/bin/chktest'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chmod"
# "Failed to extract plugin meta data from '/usr/bin/chmod'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/choom"
# "Failed to extract plugin meta data from '/usr/bin/choom'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chown"
# "Failed to extract plugin meta data from '/usr/bin/chown'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chrt"
# "Failed to extract plugin meta data from '/usr/bin/chrt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chsh"
# "Failed to extract plugin meta data from '/usr/bin/chsh'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/chvt"
# "Failed to extract plugin meta data from '/usr/bin/chvt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ciptool"
# "Failed to extract plugin meta data from '/usr/bin/ciptool'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/circo"
# "Failed to extract plugin meta data from '/usr/sbin/libgvc6-config-update'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ckbcomp"
# QElfParser: '/usr/bin/ckbcomp' is not an ELF object
# "'/usr/bin/ckbcomp' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cksum"
# "Failed to extract plugin meta data from '/usr/bin/cksum'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/clear"
# "Failed to extract plugin meta data from '/usr/bin/clear'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/clear_console"
# "Failed to extract plugin meta data from '/usr/bin/clear_console'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cluster"
# "Failed to extract plugin meta data from '/usr/bin/cluster'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cmake"
# "Failed to extract plugin meta data from '/usr/bin/cmake'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cmp"
# "Failed to extract plugin meta data from '/usr/bin/cmp'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cmsutil"
# "Failed to extract plugin meta data from '/usr/bin/cmsutil'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cmuwmtopbm"
# "Failed to extract plugin meta data from '/usr/bin/cmuwmtopbm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/code"
# QElfParser: '/usr/share/code/bin/code' is not an ELF object
# "'/usr/share/code/bin/code' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/codepage"
# "Failed to extract plugin meta data from '/usr/bin/codepage'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/col"
# "Failed to extract plugin meta data from '/usr/bin/col'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/colcon"
# QElfParser: '/usr/bin/colcon' is not an ELF object
# "'/usr/bin/colcon' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/colcrt"
# "Failed to extract plugin meta data from '/usr/bin/colcrt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/colormgr"
# "Failed to extract plugin meta data from '/usr/bin/colormgr'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/colrm"
# "Failed to extract plugin meta data from '/usr/bin/colrm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/column"
# "Failed to extract plugin meta data from '/usr/bin/column'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/comm"
# "Failed to extract plugin meta data from '/usr/bin/comm'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/compare"
# "Failed to extract plugin meta data from '/usr/bin/compare-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/compare-im6"
# "Failed to extract plugin meta data from '/usr/bin/compare-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/compare-im6.q16"
# "Failed to extract plugin meta data from '/usr/bin/compare-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/compose"
# QElfParser: '/usr/bin/run-mailcap' is not an ELF object
# "'/usr/bin/run-mailcap' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/composite"
# "Failed to extract plugin meta data from '/usr/bin/composite-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/composite-im6"
# "Failed to extract plugin meta data from '/usr/bin/composite-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/composite-im6.q16"
# "Failed to extract plugin meta data from '/usr/bin/composite-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/compute-sanitizer"
# "Failed to extract plugin meta data from '/usr/bin/compute-sanitizer'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/computeprof"
# QElfParser: '/usr/bin/nvvp' is not an ELF object
# "'/usr/bin/nvvp' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/conjure"
# "Failed to extract plugin meta data from '/usr/bin/conjure-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/conjure-im6"
# "Failed to extract plugin meta data from '/usr/bin/conjure-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/conjure-im6.q16"
# "Failed to extract plugin meta data from '/usr/bin/conjure-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/containerd"
# "Failed to extract plugin meta data from '/usr/bin/containerd'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/containerd-shim"
# "Failed to extract plugin meta data from '/usr/bin/containerd-shim'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/containerd-shim-runc-v1"
# "Failed to extract plugin meta data from '/usr/bin/containerd-shim-runc-v1'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/containerd-shim-runc-v2"
# "Failed to extract plugin meta data from '/usr/bin/containerd-shim-runc-v2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/convert"
# "Failed to extract plugin meta data from '/usr/bin/convert-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/convert-im6"
# "Failed to extract plugin meta data from '/usr/bin/convert-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/convert-im6.q16"
# "Failed to extract plugin meta data from '/usr/bin/convert-im6.q16'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/corelist"
# QElfParser: '/usr/bin/corelist' is not an ELF object
# "'/usr/bin/corelist' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/count-14"
# "Failed to extract plugin meta data from '/usr/lib/llvm-14/bin/count'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cp"
# "Failed to extract plugin meta data from '/usr/bin/cp'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cpack"
# "Failed to extract plugin meta data from '/usr/bin/cpack'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cpan"
# QElfParser: '/usr/bin/cpan' is not an ELF object
# "'/usr/bin/cpan' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cpan5.34-x86_64-linux-gnu"
# QElfParser: '/usr/bin/cpan5.34-x86_64-linux-gnu' is not an ELF object
# "'/usr/bin/cpan5.34-x86_64-linux-gnu' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cpio"
# "Failed to extract plugin meta data from '/usr/bin/cpio'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cpp"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-cpp-11'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cpp-11"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-cpp-11'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cpp-12"
# "Failed to extract plugin meta data from '/usr/bin/x86_64-linux-gnu-cpp-12'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cppcheck"
# "Failed to extract plugin meta data from '/usr/bin/cppcheck'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cppcheck-htmlreport"
# QElfParser: '/usr/bin/cppcheck-htmlreport' is not an ELF object
# "'/usr/bin/cppcheck-htmlreport' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/crlutil"
# "Failed to extract plugin meta data from '/usr/bin/crlutil'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/crontab"
# "Failed to extract plugin meta data from '/usr/bin/crontab'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cs2cs"
# "Failed to extract plugin meta data from '/usr/bin/cs2cs'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/csplit"
# "Failed to extract plugin meta data from '/usr/bin/csplit'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ctest"
# "Failed to extract plugin meta data from '/usr/bin/ctest'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ctr"
# "Failed to extract plugin meta data from '/usr/bin/ctr'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ctstat"
# "Failed to extract plugin meta data from '/usr/bin/lnstat'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cu++filt"
# "Failed to extract plugin meta data from '/usr/bin/cu++filt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cuda-gcore"
# QElfParser: '/usr/bin/cuda-gcore' is not an ELF object
# "'/usr/bin/cuda-gcore' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cuda-gdb"
# "Failed to extract plugin meta data from '/usr/bin/cuda-gdb'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cuda-gdbserver"
# "Failed to extract plugin meta data from '/usr/bin/cuda-gdbserver'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cuda-memcheck"
# "Failed to extract plugin meta data from '/usr/bin/cuda-memcheck'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cudafe++"
# "Failed to extract plugin meta data from '/usr/bin/cudafe++'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cuobjdump"
# "Failed to extract plugin meta data from '/usr/bin/cuobjdump'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cupstestppd"
# "Failed to extract plugin meta data from '/usr/bin/cupstestppd'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/curl"
# "Failed to extract plugin meta data from '/usr/bin/curl'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/curl-config"
# QElfParser: '/usr/bin/curl-config' is not an ELF object
# "'/usr/bin/curl-config' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cut"
# "Failed to extract plugin meta data from '/usr/bin/cut'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cvlc"
# QElfParser: '/usr/bin/cvlc' is not an ELF object (file too small)
# "'/usr/bin/cvlc' is not an ELF object (file too small)"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cvt"
# "Failed to extract plugin meta data from '/usr/bin/cvt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/cvtsudoers"
# "Failed to extract plugin meta data from '/usr/bin/cvtsudoers'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dash"
# "Failed to extract plugin meta data from '/usr/bin/dash'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/date"
# "Failed to extract plugin meta data from '/usr/bin/date'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbus-cleanup-sockets"
# "Failed to extract plugin meta data from '/usr/bin/dbus-cleanup-sockets'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbus-daemon"
# "Failed to extract plugin meta data from '/usr/bin/dbus-daemon'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbus-monitor"
# "Failed to extract plugin meta data from '/usr/bin/dbus-monitor'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbus-run-session"
# "Failed to extract plugin meta data from '/usr/bin/dbus-run-session'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbus-send"
# "Failed to extract plugin meta data from '/usr/bin/dbus-send'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbus-update-activation-environment"
# "Failed to extract plugin meta data from '/usr/bin/dbus-update-activation-environment'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbus-uuidgen"
# "Failed to extract plugin meta data from '/usr/bin/dbus-uuidgen'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dbxtool"
# "Failed to extract plugin meta data from '/usr/bin/dbxtool'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dc"
# "Failed to extract plugin meta data from '/usr/bin/dc'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dconf"
# "Failed to extract plugin meta data from '/usr/bin/dconf'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/dd"
# "Failed to extract plugin meta data from '/usr/bin/dd'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/ddstdecode"
# "Failed to extract plugin meta data from '/usr/bin/ddstdecode'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/deallocvt"
# "Failed to extract plugin meta data from '/usr/bin/deallocvt'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/deb-systemd-helper"
# QElfParser: '/usr/bin/deb-systemd-helper' is not an ELF object
# "'/usr/bin/deb-systemd-helper' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/bin/deb-systemd-invoke"
# QElfParser: '/usr/bin/deb-systemd-invoke' is not an ELF object
# "'/usr/bin/deb-systemd-invoke' is not an ELF object"
#          not a plugin
# ...
# Speed: 5.2ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 9.3ms
# Speed: 3.2ms preprocess, 9.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections),
9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 15.8ms
# Speed: 8.0ms preprocess, 15.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.3ms
# Speed: 2.5ms preprocess, 21.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 29.8ms
# Speed: 5.3ms preprocess, 29.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 2.5ms preprocess, 18.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 30.5ms
# Speed: 2.1ms preprocess, 30.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.4ms
# Speed: 6.9ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 12.0ms
# Speed: 6.9ms preprocess, 12.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.0ms
# Speed: 3.7ms preprocess, 20.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 19.9ms
# Speed: 5.6ms preprocess, 19.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 6.2ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 19.4ms
# Speed: 6.7ms preprocess, 19.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.9ms
# Speed: 3.7ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.1ms
# Speed: 3.4ms preprocess, 10.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.1ms
# Speed: 3.9ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 11.6ms
# Speed: 2.9ms preprocess, 11.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 6.5ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 22.0ms
# Speed: 11.4ms preprocess, 22.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.8ms
# Speed: 4.5ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 19.1ms
# Speed: 10.0ms preprocess, 19.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.8ms preprocess, 13.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.0ms
# Speed: 3.3ms preprocess, 10.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.7ms
# Speed: 3.8ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.4ms
# Speed: 5.6ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 11.3ms
# Speed: 4.2ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.4ms
# Speed: 4.2ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 12.6ms
# Speed: 5.4ms preprocess, 12.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.2ms
# Speed: 6.3ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 21.8ms
# Speed: 7.8ms preprocess, 21.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 7.4ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.0ms
# Speed: 5.5ms preprocess, 10.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.1ms
# Speed: 4.5ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.7ms
# Speed: 3.8ms preprocess, 20.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 14.1ms
# Speed: 5.9ms preprocess, 14.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.1ms
# Speed: 4.9ms preprocess, 19.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 17.7ms
# Speed: 16.8ms preprocess, 17.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 4.6ms preprocess, 18.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 9.9ms
# Speed: 8.5ms preprocess, 9.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 3.4ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 13.0ms
# Speed: 6.3ms preprocess, 13.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 4.3ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 13.9ms
# Speed: 3.6ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.3ms
# Speed: 7.0ms preprocess, 13.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 14.9ms
# Speed: 2.4ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.9ms
# Speed: 3.6ms preprocess, 18.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 13.3ms
# Speed: 6.6ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 4.9ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 13.9ms
# Speed: 5.6ms preprocess, 13.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.2ms
# Speed: 4.8ms preprocess, 12.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 9.7ms
# Speed: 2.3ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#      ID    Object_Type   Status           Signal Color Pass/Fail
# 0    12  Traffic Light     STOP                  Green      Fail
# 1    13  Traffic Light  DRIVING                  Green      Fail
# 2    38  Traffic Light  DRIVING  Green and Green Arrow      Pass
# 3    58        Vehicle  Driving                    NaN      Fail
# 4    70  Traffic Light  DRIVING                 Yellow      Fail
# 5    92  Traffic Light     STOP    Red and Green Arrow      Pass
# 6   110        Vehicle  Stopped                    NaN      Pass
# 7   117  Traffic Light     STOP                    Red      Pass
# 8   122  Traffic Light  DRIVING                    Red      Fail
# 9   123  Traffic Light     STOP                    Red      Pass
# 10  129        Vehicle  Stopped                    NaN      Pass
# 11  137  Traffic Light     STOP                    Red      Pass

# %% [markdown]
# JSON 파일도 생성!!! 경로는 변경해야돼유~

# %%
import json
import cv2
import pandas as pd
from collections import defaultdict, deque, Counter
from statistics import mode
from ultralytics import YOLO

class VehicleDetector:
    def __init__(self, model_path, min_vehicle_size=1000):
        self.model_path = model_path
        self.min_vehicle_size = min_vehicle_size
        self.model = YOLO(model_path)
        self.img_width = 1280  # 영상의 가로 해상도
        self.img_height = 720  # 영상의 세로 해상도
        self.center_line_x = self.img_width // 2  # 영상의 중앙선 x 좌표
        self.center_line_tolerance = 70  # 중앙선 허용 오차
        self.last_bbox_size = 0
        self.classes = {
            0: "person",
            2: "car",
            5: "bus",
            7: "truck",
            # Add more classes if needed
        }
        self.pass_fail_status_history = defaultdict(lambda: deque(maxlen=15))  # 최대 10개 항목 저장
        self.pass_fail_status = {}

    def check_front_vehicle(self, frame):
        frame = cv2.resize(frame, (self.img_width, self.img_height))
        results = self.model.track(frame, persist=True)

        is_crash = 0  # 초기 값 설정
        x1, y1, x2, y2, track_id, class_id = 0, 0, 0, 0, 0, 0  # 초기 값 설정

        for box in results[0].boxes:
            # 바운딩 박스의 중심 좌표 계산
            x_center = (box.xyxy[0][0] + box.xyxy[0][2]) // 2
            y_center = (box.xyxy[0][1] + box.xyxy[0][3]) // 2
            # 중앙선을 통과하는지 확인
            if self.center_line_x - self.center_line_tolerance < x_center < self.center_line_x + self.center_line_tolerance:
                # 바운딩 박스의 크기 계산
                box_size = box.xywh[0][2] * box.xywh[0][3]
                # 자동차 클래스 필터링 및 크기 조건 검사
                if 20000 < box_size < 80000:
                    is_crash = 1  # 전방 차량이 감지됨
                elif box_size > 80000:
                    is_crash = 2  # 전방 차량이 감지됨 충돌 직전
                    if box.id is not None:  # None이 아닌 경우에만 track_id 설정
                        track_id = int(box.id)  # 클래스 ID 추출
                        class_id = int(box.cls)
                
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                break  # 첫 번째 바운딩 박스만 고려

        return is_crash, x1, y1, x2, y2, track_id, class_id

    def determine_driving_status(self, current_bbox_size):
        # 이전 프레임과의 바운딩 박스 크기 비교
        size_difference = abs(current_bbox_size - self.last_bbox_size)
        # 크기 변화량을 기준으로 주행 상태 판단
        if size_difference > 1000:  # 예시로 1000을 기준으로 주행 중으로 판단
            return True  # 주행 중
        else:
            return False  # 정지 중

    def update_last_bbox_size(self, current_bbox_size):
        self.last_bbox_size = current_bbox_size

    def determine_pass_fail_status(self, is_driving):
        return 'Fail' if is_driving else 'Pass'

class TrafficLightDetector:
    def __init__(self, model_path, history_length=30):
        self.model = YOLO(model_path)
        self.desired_width = 1280
        self.desired_height = 720
        self.history_length = history_length
        self.size_history = defaultdict(lambda: deque(maxlen=history_length))
        self.pass_fail_status_history = defaultdict(lambda: deque(maxlen=15))  # pass/fail 상태 기록
        self.pass_fail_status = defaultdict(lambda: "Calculating")  # 초기값을 "Calculating"으로 설정
        self.signal_detected = False
        self.signal_color = defaultdict(lambda: None)
        self.classes = {
            0: 'Red',
            1: 'Red and Green Arrow',
            2: 'Green',
            3: 'Yellow',
            4: 'Green and Green Arrow',
            5: 'Green Arrow'
        }
        self.detected_ids = set()  # 추적된 신호등 ID를 저장하는 집합

    def detect_traffic_light(self, frame):
        frame = cv2.resize(frame, (self.desired_width, self.desired_height))
        results = self.model.track(frame, persist=True)
        detected_objects = []

        if results[0].boxes.is_track:
            self.signal_detected = True
            max_size = 0
            max_obj_id = None
            for detection in results[0].boxes.data:
                x1, y1, x2, y2, obj_id, _, class_id = map(int, detection[:7])
                size = (x2 - x1) * (y2 - y1)  # 신호등 크기 계산
                # 가장 크기가 큰 객체만 선택
                if size > max_size:
                    max_size = size
                    max_obj_id = obj_id

            if max_obj_id is not None:
                detected_objects.append((max_obj_id, max_size))
                self.detected_ids.add(max_obj_id)  # 감지된 신호등 ID 추가
                self.signal_color[max_obj_id] = self.classes.get(class_id, None)

                # 업데이트된 크기 히스토리
                self.size_history[max_obj_id].append(max_size)

                # 객체가 발견된 경우에만 Pass/Fail 상태 업데이트
                is_driving = self.check_driving_status(max_obj_id)
                pass_fail = self.determine_pass_fail_status(is_driving, class_id)
                self.pass_fail_status_history[max_obj_id].append(pass_fail)  # 최근 20프레임의 Pass/Fail 기록

                # 객체의 Pass/Fail 값을 최근 10프레임 동안의 데이터를 기반으로 판단
                if len(self.pass_fail_status_history[max_obj_id]) == 15:
                    self.pass_fail_status[max_obj_id] = mode(self.pass_fail_status_history[max_obj_id])

        else:
            self.signal_detected = False

        return detected_objects, results


    def check_driving_status(self, obj_id):
        # 신호등 크기의 변화를 확인하여 주행 상태 판단
        if len(self.size_history[obj_id]) == self.history_length:
            # 최근 크기 변화 계산
            recent_changes = max(self.size_history[obj_id]) - min(self.size_history[obj_id])
            # 주행 상태 판단: 크기 변화가 있는 경우 주행 중으로 판단
            if recent_changes > threshold:
                return True
        # 주행 상태 판단: 크기 변화가 없는 경우 정지 중으로 판단
        return False

    def determine_pass_fail_status(self, is_driving, class_id):
        if is_driving and class_id in [0, 1]:
            Pass_Fail = "Fail"
        elif is_driving and class_id in [2, 3, 4, 5]:
            Pass_Fail = "Pass"
        elif not is_driving and class_id in [0, 1]:
            Pass_Fail = "Pass"
        elif not is_driving and class_id in [2, 3, 4, 5]:
            Pass_Fail = "Fail"
        return Pass_Fail
def save_results_to_json(vehicle_results, traffic_light_results, file_path, video_length):
    results = {
        "vehicle_results": vehicle_results,
        "traffic_light_results": traffic_light_results,
        "video_length": video_length
    }
    with open(file_path, 'w') as json_file:
        json.dump(results, json_file, indent=4)

def main(video_path, vehicle_model_path, traffic_light_model_path):
    cap = cv2.VideoCapture(video_path)
    vehicle_detector = VehicleDetector(vehicle_model_path)
    traffic_light_detector = TrafficLightDetector(traffic_light_model_path)
    df_data = []
    vehicle_results = []
    traffic_light_results = []
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))


    frame_count = 0

    while cap.isOpened():
        success, frame = cap.read()
        if not success:
            break
        
        frame_count += 1

        

        # 차량 감지
        vehicle_is_crash, vehicle_x1, vehicle_y1, vehicle_x2, vehicle_y2, vehicle_track_id, vehicle_class_id = vehicle_detector.check_front_vehicle(frame)
        
        # 차량 바운딩 박스 색상 설정
        vehicle_color = (0, 255, 0)  # 초록색
        if vehicle_is_crash == 1:
            vehicle_color = (0, 165, 255)  # 주황색
        elif vehicle_is_crash == 2:
            vehicle_color = (0, 0, 255)  # 빨간색

        # 차량 바운딩 박스 그리기
        cv2.rectangle(frame, (vehicle_x1, vehicle_y1), (vehicle_x2, vehicle_y2), vehicle_color, 2)
        

        # 차량 주행 상태 판별 및 업데이트
        if vehicle_is_crash == 2:  # 충돌 직전인 경우에만 주행 상태를 판별하고 출력하고 저장
            current_bbox_size = (vehicle_x2 - vehicle_x1) * (vehicle_y2 - vehicle_y1)
            vehicle_is_driving = vehicle_detector.determine_driving_status(current_bbox_size)
            vehicle_detector.update_last_bbox_size(current_bbox_size)

            if vehicle_track_id:
                vehicle_pass_fail = vehicle_detector.determine_pass_fail_status(vehicle_is_driving)
                vehicle_detector.pass_fail_status_history[vehicle_track_id].append(vehicle_pass_fail)

                # 최종 10개 데이터 기반 판단
                if len(vehicle_detector.pass_fail_status_history[vehicle_track_id]) == 15:
                    vehicle_detector.pass_fail_status[vehicle_track_id] = mode(vehicle_detector.pass_fail_status_history[vehicle_track_id])
                else:
                    vehicle_detector.pass_fail_status[vehicle_track_id] = vehicle_pass_fail

                # 차량 주행 상태에 따라 표시할 메시지 설정
                vehicle_status_msg = "Driving" if vehicle_is_driving else "Stopped"
                vehicle_pass_fail = vehicle_detector.pass_fail_status[vehicle_track_id]

                # 화면에 차량 주행 상태 출력
                cv2.putText(frame, f"Vehicle ID: {vehicle_track_id} Status: {vehicle_status_msg} Pass/Fail: {vehicle_pass_fail}", 
                            (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, vehicle_color, 2, cv2.LINE_AA)

                # 데이터프레임에 차량 주행 상태 저장
                df_data.append({'Object_Type': vehicle_detector.classes.get(vehicle_class_id, None), 'ID': vehicle_track_id, 'Class ID' : vehicle_class_id,'Status': vehicle_status_msg, 'Pass/Fail': vehicle_pass_fail})
                # json 파일에도 추가
                vehicle_result = {
                    "frame_number": frame_count,
                    "time": cap.get(cv2.CAP_PROP_POS_MSEC),  # 현재 동영상 시간 (밀리초)
                    "object_type":  vehicle_detector.classes.get(vehicle_class_id, None),
                    "class_id": vehicle_class_id,
                    "status": vehicle_status_msg,
                    "pass_fail": vehicle_pass_fail,
                    "bounding_box": {
                        "x1": vehicle_x1,
                        "y1": vehicle_y1,
                        "x2": vehicle_x2,
                        "y2": vehicle_y2
                    }
                }
                vehicle_results.append(vehicle_result)

        # 신호등 감지
        detected_objects, results = traffic_light_detector.detect_traffic_light(frame)
        if results[0].boxes.is_track:
            for detection in results[0].boxes.data:
                traffic_x1, traffic_y1, traffic_x2, traffic_y2, obj_id, _, traffic_class_id = map(int, detection[:7])
                cv2.rectangle(frame, (traffic_x1, traffic_y1), (traffic_x2, traffic_y2), (0,255,0), 2)

        # 신호등 바운딩 박스 및 정보 출력
        for obj_id, size in detected_objects:
            # 신호등 바운딩 박스 및 정보 출력
            status = "DRIVING" if traffic_light_detector.check_driving_status(obj_id) else "STOP"
            signal_color = traffic_light_detector.signal_color[obj_id]
            
            # 데이터프레임에 신호등 정보 저장
            if signal_color is not None:
                pass_fail = traffic_light_detector.pass_fail_status[obj_id]
                cv2.putText(frame, f"Traffic Light ID: {obj_id} Status: {status}", (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
                cv2.putText(frame, f"Signal color: {signal_color}", (20, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)
                cv2.putText(frame, f"Pass/Fail: {pass_fail}", (20, 200), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
                if pass_fail != "Calculating":
                # 데이터프레임에 신호등 정보 저장
                    df_data.append({'Object_Type': traffic_light_detector.classes.get(traffic_class_id, None), 'ID': obj_id, 'Class ID' :traffic_class_id, 'Status': status, 'Signal Color': signal_color, 'Pass/Fail': pass_fail})
                    
                    # 신호등 결과 추가
                    traffic_light_result = {
                        "frame_number": frame_count,
                        "time": cap.get(cv2.CAP_PROP_POS_MSEC),  # 현재 동영상 시간 (밀리초)
                        "object_type": traffic_light_detector.classes.get(traffic_class_id, None),
                        "class_id": traffic_class_id,
                        "status": status,
                        "signal_color": signal_color,
                        "pass_fail": pass_fail,
                        "bounding_box": {
                            "x1": traffic_x1,
                            "y1": traffic_y1,
                            "x2": traffic_x2,
                            "y2": traffic_y2
                        }
                    }
                    traffic_light_results.append(traffic_light_result)

        # 화면에 프레임 출력
        cv2.imshow("Frame", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    # 결과 데이터프레임 생성
    df = pd.DataFrame(df_data)

    # 중복된 ID에 대해 최다빈도수 값만 남기고 나머지는 제거
    df = df.groupby('ID').agg(lambda x: Counter(x).most_common(1)[0][0]).reset_index()

    # 데이터프레임 출력
    print(df)

    # 데이터프레임을 CSV 파일로 저장
    df.to_csv('combined_detection_results.csv', index=False)
    
    # 데이터프레임을 JSON 파일로 저장
    save_results_to_json(vehicle_results, traffic_light_results, '/home/min/dev_ws/machine_learning/project_3rd/data/TEST_VIDEO/final_test_video/analysis_results.json', video_length)

if __name__ == "__main__":
    video_path = "/home/min/dev_ws/machine_learning/project_3rd/data/TEST_VIDEO/6_Fail_Pedestrian_Red_Light.MOV"
    vehicle_model_path = "/home/min/dev_ws/machine_learning/project_3rd/src/judge_video/lane_detect/yolov8n.pt"
    traffic_light_model_path = "/home/min/dev_ws/machine_learning/project_3rd/src/model_learning/traffic_light/traffic_best_ver2.pt"
    threshold = 30  # 주행 상태 판단을 위한 임계값 설정
    main(video_path, vehicle_model_path, traffic_light_model_path)
# Out:
# 0: 384x640 2 cars, 1 bus, 1 truck, 9.7ms
# Speed: 5.3ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 9.1ms
# Speed: 4.4ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 8.8ms
# Speed: 3.3ms preprocess, 8.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.8ms
# Speed: 2.2ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.3ms
# Speed: 3.2ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2
7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 9.6ms
# Speed: 3.8ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red, 1 green, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 7.1ms
# Speed: 3.4ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red, 1 green, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 green, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 10.9ms
# Speed: 4.2ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red, 1 green, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 reds, 2 greens, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red, 2 greens, 2 green and green arrows, 13.1ms
# Speed: 3.9ms preprocess, 13.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 8.3ms
# Speed: 3.7ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 reds, 1 green, 2 green and green arrows, 14.9ms
# Speed: 2.7ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 reds, 2 greens, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.6ms
# Speed: 3.4ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red, 2 greens, 1 green and green arrow, 13.8ms
# Speed: 3.1ms preprocess, 13.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 10.1ms
# Speed: 4.5ms preprocess, 10.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red, 2 greens, 1 green and green arrow, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 green, 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 green, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 13.8ms
# Speed: 4.9ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 green, 24.6ms
# Speed: 5.9ms preprocess, 24.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 21.8ms
# Speed: 8.6ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 9.8ms preprocess, 23.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 4.1ms preprocess, 14.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.5ms
# Speed: 1.4ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.7ms
# Speed: 8.0ms preprocess, 20.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 green, 24.5ms
# Speed: 4.2ms preprocess, 24.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 15.7ms
# Speed: 7.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 13.1ms
# Speed: 9.7ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 11.9ms
# Speed: 4.7ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 green, 1 green and green arrow, 28.6ms
# Speed: 5.7ms preprocess, 28.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 20.4ms
# Speed: 8.8ms preprocess, 20.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 11.6ms
# Speed: 5.1ms preprocess, 11.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 green, 1 green and green arrow, 7.2ms
# Speed: 3.4ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 13.2ms
# Speed: 4.1ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 7.1ms
# Speed: 1.1ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 7.1ms
# Speed: 3.0ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 6.8ms
# Speed: 1.1ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 9.7ms
# Speed: 4.2ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 10.8ms
# Speed: 4.2ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 7.4ms
# Speed: 1.1ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 greens, 9.5ms
# Speed: 2.9ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars,
7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 1.3ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.6ms
# Speed: 5.3ms preprocess, 12.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 16.9ms
# Speed: 2.9ms preprocess, 16.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 2.2ms preprocess, 10.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.2ms
# Speed: 3.9ms preprocess, 7.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.7ms
# Speed: 3.1ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.0ms
# Speed: 2.9ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 14.1ms
# Speed: 7.9ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.7ms
# Speed: 4.0ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.7ms
# Speed: 3.3ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 5.1ms preprocess, 10.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.8ms
# Speed: 2.4ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 5.7ms
# Speed: 1.9ms preprocess, 5.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 8.5ms
# Speed: 4.5ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 4.5ms preprocess, 13.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 14.1ms
# Speed: 5.8ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.4ms
# Speed: 1.4ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.4ms
# Speed: 4.1ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.3ms
# Speed: 7.0ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.7ms
# Speed: 3.9ms preprocess, 13.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 8.2ms preprocess, 18.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 16.3ms
# Speed: 5.3ms preprocess, 16.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.7ms
# Speed: 2.7ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.5ms
# Speed: 5.5ms preprocess, 11.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 10.6ms
# Speed: 5.5ms preprocess, 10.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 6.2ms
# Speed: 3.4ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 13.3ms
# Speed: 7.9ms preprocess, 13.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 2.7ms preprocess, 16.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 12.2ms
# Speed: 3.4ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.3ms
# Speed: 3.2ms preprocess, 8.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#     ID            Object_Type  Class ID   Status           Signal Color  \
# 0   13                  Green         2  DRIVING                  Green
# 1   43  Green and Green Arrow         4  DRIVING  Green and Green Arrow
# 2   59                 person         0  Driving                    NaN
# 3   70                 Yellow         3  DRIVING                 Yellow
# 4   90    Red and Green Arrow         1     STOP    Red and Green Arrow
# 5  105                    car         2  Stopped                    NaN
# 6  114                    Red         0     STOP                    Red
# 7  118                    Red         0     STOP                    Red
# 8  125                    car         2  Stopped                    NaN
# 9  133                    Red         0     STOP                    Red
#
#   Pass/Fail
# 0      Fail
# 1      Pass
# 2      Fail
# 3      Fail
# 4      Pass
# 5      Pass
# 6      Pass
# 7      Pass
# 8      Pass
# 9      Pass
